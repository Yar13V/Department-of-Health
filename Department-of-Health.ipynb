# %%
import pandas as pd
import glob
import os

# %%
def read_all_xlsx():
    path = r'C:\reports' 
    all_files = glob.glob(os.path.join(path, "ac*.csv"))

    list_dfs = []

    for filename in all_files:
        df = pd.read_excel(filename, index_col=None, header=0)
        list_dfs.append(df)

    df_final = pd.concat(list_dfs, axis=0, ignore_index=True)
    
def palindrom(word):

# %%
word = 'asddsa'

# %%
def palindrom(word):
    n = 0
    for i in range(len(word)):
        if word[i] == word[-i-1]:
            n +=1
    if n == len(word):
        return True
    else:
        return False
